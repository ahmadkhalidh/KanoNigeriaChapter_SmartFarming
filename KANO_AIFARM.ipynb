# %% [markdown]
# <a href="https://colab.research.google.com/github/OmdenaAI/KanoNigeriaChapter_SmartFarming/blob/main/KANO_AIFARM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# 0. **Data Disctionary**
#
# Data_Source: NASA/POWER Source Native Resolution Daily Data
#
# Dates: in LST (month/day/year)
#
# PRECIPITATION: PRECTOTCORR (mm/day)
#
# MAX_TEMPERATURE: T2M_MAX (C)
#
# MIN_TEMPERATURE:T2M_MIN (C)
#
# HUMIDITY: RH2M (%)

# %% [markdown]
# 1. **Data Wrangling**

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %%
def wrangler(path) -> pd.DataFrame:

  df = pd.read_csv(path) # Read csv file

  df['date'] = df.apply(lambda x: f"{int(x['YEAR'])}-{int(x['DOY'])}", axis=1) # Date feature engineering
  df['date'] = pd.to_datetime(df['date'], format='%Y-%j') # Date feature engineering
  df.index = df['date'] # Date as index
  df.drop(['date', 'YEAR', 'DOY'], axis=1, inplace=True) # Drop irrelevant columns

  # checks if there are missing values or duplicates
  for col in df.columns:
    if df[col].isna().any():
      print(f'{col} has {df[col].isna().sum()} missing values, please check to decide imputation or drop')
    elif df.duplicated().any():
      print(f'{col} has {df.duplicated().sum()} duplicate values, please check to decide if drop is necessary')
    else:
      continue
  df.rename(columns={'PRECTOTCORR': 'PRECIPITATION'}, inplace=True) # Rename column
  print(df.shape)



  return df

# %%
df = wrangler('/content/Kano_Metro_data_edited.csv')
df.head()
# Out:
# (4018, 4)
#             PRECIPITATION  T2M_MAX  T2M_MIN  RH2M
# date
# 2014-01-01           0.00    31.58    10.23 18.48
# 2014-01-02           0.00    29.80    12.59 15.86
# 2014-01-03           0.00    30.12    12.44 16.93
# 2014-01-04           0.00    30.72    12.47 19.74
# 2014-01-05           0.00    29.41    12.13 22.80

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#        PRECIPITATION  T2M_MAX  T2M_MIN     RH2M
# count       4,018.00 4,018.00 4,018.00 4,018.00
# mean            2.07    34.75    19.62    45.38
# std             8.85     4.18     4.92    22.04
# min             0.00    18.83     5.88     6.26
# 25%             0.00    31.78    15.68    25.46
# 50%             0.00    34.77    21.48    44.49
# 75%             0.79    37.97    23.25    64.02
# max           181.37    44.18    29.01    94.77

# %%
# Cleaned file ready for EDA
df.to_csv('Kano_Metro_data_Cleaned.csv', index='date')
